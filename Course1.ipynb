# %% [markdown]
# <a href="https://colab.research.google.com/github/Bert-Shengyuan/Python-Course/blob/main/Course1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hallo Yuxuan!")
# Out:
# Hallo Yuxuan!
